# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, yfinance as yf

# %%
tickers = ["SPY", "QQQ", "EFA", "EEM", "TLT", "IEF", "LQD", "GLD", "VNQ", "DBC"]
start = "2016-09-01"
end = "2026-09-01"

# %%
prices = yf.download(tickers, start=start, end=end)
# Out:
# [*********************100%***********************]  10 of 10 completed

# %%
prices = yf.download(tickers, start=start, end=end, threads=False)
# Out:
# [*********************100%***********************]  10 of 10 completed

# %%
prices.head()
# Out:
# Price           Close                                                          \
# Ticker            DBC        EEM        EFA         GLD        IEF        LQD
# Date
# 2016-09-01  12.030577  29.565416  43.757137  125.290001  88.417885  86.618958
# 2016-09-02  12.165847  30.047327  44.263611  126.570000  88.188492  86.464745
# 2016-09-06  12.250391  30.689886  44.561523  128.710007  88.599800  86.766190
# 2016-09-07  12.360297  30.593502  44.583874  128.270004  88.647278  86.646996
# 2016-09-08  12.580112  30.513180  44.457268  127.589996  88.212250  86.037178
#
# Price                                                      ...   Volume  \
# Ticker             QQQ         SPY         TLT        VNQ  ...      DBC
# Date                                                       ...
# 2016-09-01  108.934364  184.716949  105.115288  59.699818  ...  2227000
# 2016-09-02  109.288956  185.549667  104.258011  60.217785  ...  3184400
# 2016-09-06  109.970139  186.110489  105.017616  60.681911  ...  1680200
# 2016-09-07  110.035461  186.093491  104.942337  61.045155  ...  1148500
# 2016-09-08  109.391632  185.668655  103.626274  60.298489  ...  2248200
#
# Price                                                                   \
# Ticker            EEM       EFA       GLD      IEF       LQD       QQQ
# Date
# 2016-09-01   67120400  18389800  12877700  1775900  10146300  20944700
# 2016-09-02   88393000  19151600  11318600  1550100   4155700  18088200
# 2016-09-06  108573800  14730600  15115300  1284000   6387400  18525200
# 2016-09-07   58618800  17917500   8859800   836800   2983400  17546900
# 2016-09-08   73367300  15572700  10561800  1287300   4632300  20125300
#
# Price
# Ticker           SPY       TLT      VNQ
# Date
# 2016-09-01  97844200   9149100  4098000
# 2016-09-02  79293900   8397000  4439500
# 2016-09-06  56702100   8542600  3874300
# 2016-09-07  76554900   5421800  2874200
# 2016-09-08  74102900  14301500  3123900
#
# [5 rows x 50 columns]

# %%
prices.shape
# Out:
# (2512, 50)

# %%
prices.columns
# Out:
# MultiIndex([( 'Close', 'DBC'),
#             ( 'Close', 'EEM'),
#             ( 'Close', 'EFA'),
#             ( 'Close', 'GLD'),
#             ( 'Close', 'IEF'),
#             ( 'Close', 'LQD'),
#             ( 'Close', 'QQQ'),
#             ( 'Close', 'SPY'),
#             ( 'Close', 'TLT'),
#             ( 'Close', 'VNQ'),
#             (  'High', 'DBC'),
#             (  'High', 'EEM'),
#             (  'High', 'EFA'),
#             (  'High', 'GLD'),
#             (  'High', 'IEF'),
#             (  'High', 'LQD'),
#             (  'High', 'QQQ'),
#             (  'High', 'SPY'),
#             (  'High', 'TLT'),
#             (  'High', 'VNQ'),
#             (   'Low', 'DBC'),
#             (   'Low', 'EEM'),
#             (   'Low', 'EFA'),
#             (   'Low', 'GLD'),
#             (   'Low', 'IEF'),
#             (   'Low', 'LQD'),
#             (   'Low', 'QQQ'),
#             (   'Low', 'SPY'),
#             (   'Low', 'TLT'),
#             (   'Low', 'VNQ'),
#             (  'Open', 'DBC'),
#             (  'Open', 'EEM'),
#             (  'Open', 'EFA'),
#             (  'Open', 'GLD'),
#             (  'Open', 'IEF'),
#             (  'Open', 'LQD'),
#             (  'Open', 'QQQ'),
#             (  'Open', 'SPY'),
#             (  'Open', 'TLT'),
#             (  'Open', 'VNQ'),
#             ('Volume', 'DBC'),
#             ('Volume', 'EEM'),
#             ('Volume', 'EFA'),
#             ('Volume', 'GLD'),
#             ('Volume', 'IEF'),
#             ('Volume', 'LQD'),
#             ('Volume', 'QQQ'),
#             ('Volume', 'SPY'),
#             ('Volume', 'TLT'),
#             ('Volume', 'VNQ')],
#            names=['Price', 'Ticker'])

# %%
close = prices["Close"]

# %%
close.head()
# Out:
# Ticker            DBC        EEM        EFA         GLD        IEF        LQD  \
# Date
# 2016-09-01  12.030577  29.565416  43.757137  125.290001  88.417885  86.618958
# 2016-09-02  12.165847  30.047327  44.263611  126.570000  88.188492  86.464745
# 2016-09-06  12.250391  30.689886  44.561523  128.710007  88.599800  86.766190
# 2016-09-07  12.360297  30.593502  44.583874  128.270004  88.647278  86.646996
# 2016-09-08  12.580112  30.513180  44.457268  127.589996  88.212250  86.037178
#
# Ticker             QQQ         SPY         TLT        VNQ
# Date
# 2016-09-01  108.934364  184.716949  105.115288  59.699818
# 2016-09-02  109.288956  185.549667  104.258011  60.217785
# 2016-09-06  109.970139  186.110489  105.017616  60.681911
# 2016-09-07  110.035461  186.093491  104.942337  61.045155
# 2016-09-08  109.391632  185.668655  103.626274  60.298489

# %%
close.to_csv("../data/prices.csv")

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Jvooj\\Documents\\Portfolio-Optimisation\\notebooks'

# %%
close.isna().sum()
# Out:
# Ticker
# DBC    0
# EEM    0
# EFA    0
# GLD    0
# IEF    0
# LQD    0
# QQQ    0
# SPY    0
# TLT    0
# VNQ    0
# dtype: int64

# %%
returns = close.pct_change().dropna()

# %%
returns.head()
# Out:
# Ticker           DBC       EEM       EFA       GLD       IEF       LQD  \
# Date
# 2016-09-02  0.011244  0.016300  0.011575  0.010216 -0.002594 -0.001780
# 2016-09-06  0.006949  0.021385  0.006730  0.016908  0.004664  0.003486
# 2016-09-07  0.008972 -0.003141  0.000502 -0.003419  0.000536 -0.001374
# 2016-09-08  0.017784 -0.002625 -0.002840 -0.005301 -0.004907 -0.007038
# 2016-09-09 -0.015457 -0.033693 -0.019434 -0.006584 -0.004752 -0.007495
#
# Ticker           QQQ       SPY       TLT       VNQ
# Date
# 2016-09-02  0.003255  0.004508 -0.008156  0.008676
# 2016-09-06  0.006233  0.003022  0.007286  0.007707
# 2016-09-07  0.000594 -0.000091 -0.000717  0.005986
# 2016-09-08 -0.005851 -0.002283 -0.012541 -0.012231
# 2016-09-09 -0.025164 -0.023935 -0.016474 -0.039603

# %%
returns.describe()
# Out:
# Ticker          DBC          EEM          EFA          GLD          IEF  \
# count   2511.000000  2511.000000  2511.000000  2511.000000  2511.000000
# mean       0.000445     0.000413     0.000416     0.000524     0.000026
# std        0.011288     0.013134     0.010718     0.010274     0.004164
# min       -0.079444    -0.124793    -0.109902    -0.102742    -0.025073
# 25%       -0.005618    -0.006227    -0.004492    -0.004520    -0.002378
# 50%        0.001254     0.000933     0.000721     0.000698     0.000093
# 75%        0.006749     0.007474     0.005842     0.005639     0.002384
# max        0.047990     0.080529     0.084731     0.063587     0.026417
#
# Ticker          LQD          QQQ          SPY          TLT          VNQ
# count   2511.000000  2511.000000  2511.000000  2511.000000  2511.000000
# mean       0.000094     0.000852     0.000630    -0.000054     0.000278
# std        0.005475     0.014211     0.011322     0.009345     0.013082
# min       -0.050030    -0.119788    -0.109424    -0.066683    -0.177277
# 25%       -0.002416    -0.005160    -0.003625    -0.005589    -0.005735
# 50%        0.000283     0.001287     0.000731     0.000123     0.000744
# 75%        0.002689     0.008023     0.005991     0.005367     0.006866
# max        0.073918     0.120031     0.105019     0.075196     0.089967

# %%
returns = close.pct_change().dropna()

# %%
mu = returns.mean() * 252
vol = returns.std() * np.sqrt(252)
cov = returns.cov() * 252
corr = returns.corr()

# %%
pd.DataFrame({"return": mu, "volatility": vol})
# Out:
#           return  volatility
# Ticker
# DBC     0.112104    0.179185
# EEM     0.103983    0.208490
# EFA     0.104724    0.170141
# GLD     0.131964    0.163088
# IEF     0.006613    0.066109
# LQD     0.023813    0.086914
# QQQ     0.214628    0.225588
# SPY     0.158865    0.179727
# TLT    -0.013675    0.148352
# VNQ     0.069937    0.207672

# %%
plt.imshow(corr, cmap='coolwarm', vmin = -1, vmax =1)
plt.colorbar(label = "correlation")
plt.xticks(range(len(corr.columns)), corr.columns, rotation=45)
plt.yticks(range(len(corr.columns)), corr.columns)

for i in range(len(corr.columns)):
    for j in range(len(corr.columns)):
        plt.text(j, i, f"{corr.iloc[i, j]:.2f}", ha='center', va='center', color='black', fontsize = 8)

plt.title("Daily Returns Correlation Sep 2016-Sep-2026")
plt.tight_layout()
plt.savefig("../data/correlation_heatmap.png", dpi=150)
plt.show()

# %%
n = len(corr.columns)
avg_corr = (corr.sum() - 1) / (n - 1)
avg_corr.sort_values()
# Out:
# Ticker
# TLT    0.150939
# DBC    0.151886
# IEF    0.183291
# GLD    0.222010
# VNQ    0.373106
# LQD    0.377667
# QQQ    0.387077
# EEM    0.394564
# SPY    0.412443
# EFA    0.429923
# dtype: float64

# %%
avg_corr.sort_values().plot(kind="barh", title="Average correlation with other ETFs")
plt.xlabel("Mean correlation")
plt.tight_layout()
plt.savefig("../data/avg_correlation.png", dpi=150)
plt.show()

# %%
import sys
sys.path.append("..")

# %reload_ext autoreload
# %autoreload 2

from src.metrics import portfolio_return, portfolio_vol, sharpe_ratio

# %%
w_spy = np.zeros(len(returns.columns))
spy_index = list(returns.columns).index("SPY")
w_spy[spy_index] = 1

print("Function return:", portfolio_return(w_spy, mu))
print("SPY mu:         ", mu["SPY"])
print("Function volatility:", portfolio_vol(w_spy, cov))
print("SPY vol:            ", vol["SPY"])

print(np.isclose(portfolio_return(w_spy, mu), mu["SPY"]))
print(np.isclose(portfolio_vol(w_spy, cov), vol["SPY"]))
# Out:
# Function return: 0.15886455758101004
# SPY mu:          0.15886455758101004
# Function volatility: 0.17972654373509578
# SPY vol:             0.17972654373509578
# True
# True

# %%
w_equal = np.ones(10) / 10

print("Equal-weight return:", portfolio_return(w_equal, mu))
print("Equal-weight volatility:", portfolio_vol(w_equal, cov))
print("Equal-weight Sharpe ratio:", sharpe_ratio(w_equal, mu, cov))
print("Average individual asset volatility:", vol.mean())

print("Volatility difference:", portfolio_vol(w_equal, cov) - vol.mean())

reduction = 1 - portfolio_vol(w_equal, cov) / vol.mean()
print(f"Diversification reduces volatility by {reduction:.1%}")
# Out:
# Equal-weight return: 0.09129550258399655
# Equal-weight volatility: 0.10577687195569663
# Equal-weight Sharpe ratio: 0.8630951255793854
# Average individual asset volatility: 0.16352647300398998
# Volatility difference: -0.05774960104829335
# Diversification reduces volatility by 35.3%

# %%
rng = np.random.default_rng(42)

# %%
w = rng.dirichlet(np.ones(10))
print("Random weights:", w)
np.isclose(w.sum(), 1)
# Out:
# Random weights: [0.16148778 0.16840904 0.13126328 0.00884244 0.13731552 0.16398639
#  0.13585916 0.033909   0.0388597  0.02006769]
# np.True_

# %%
rets = []
volas = []
shrp = []

for i in range(5000):
    w = rng.dirichlet(np.ones(10))
    rets.append(portfolio_return(w, mu))
    volas.append(portfolio_vol(w, cov))
    shrp.append(sharpe_ratio(w, mu, cov))

# %%
plt.scatter(volas, rets, c=shrp, cmap="viridis", s=5)
plt.colorbar(label="Sharpe ratio")
plt.xlabel("Volatility(annualised)")
plt.ylabel("Return(annualised)")
plt.title("Random Portfolios: Return vs Volatility")
plt.scatter(portfolio_vol(w_equal, cov), portfolio_return(w_equal, mu), color="red", s=100, label="Equal-weighted portfolio")
plt.legend()
plt.savefig("../data/monte_carlo.png", dpi=150)
plt.show()
